# %% [markdown]
# ### 맷플롯립 matplotlib 기초
# - 차트 시각화 라이브러리
# - 한글이 안되는 약간의 문제,,? 그치만 해결방안 있다아
# - 한글 폰트 연결 필요
#
# ### matplotlib 설치
# ```shell
# %pip install matplotlib
# ```

# %%
# %pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: matplotlib in c:\dev\langs\python311\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dev\langs\python311\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\dev\langs\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dev\langs\python311\lib\site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\dev\langs\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\dev\langs\python311\lib\site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\dev\langs\python311\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dev\langs\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\administrator\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Seaborn 설치 (matplotlib을 좀 더 이쁘게 시각화)
#
# ```shell
# %pip install seaborn
# ```

# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\dev\langs\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\dev\langs\python311\lib\site-packages (from seaborn) (1.26.3)
# Requirement already satisfied: pandas>=1.2 in c:\dev\langs\python311\lib\site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\dev\langs\python311\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dev\langs\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\dev\langs\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dev\langs\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\dev\langs\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\dev\langs\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dev\langs\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\administrator\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\dev\langs\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\dev\langs\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### 한글깨짐 잡기
# - 나눔폰트 옵션 사용
# - 폰트 관리자 설정

# %%
# matplotlib 사용(시 아래내용 설정 필수)
import warnings
import matplotlib.pyplot as plt # plt로 줄여씀
from matplotlib import rcParams, font_manager, rc 

# 맑음고딕 경로 
font_path = 'C:/Windows/Fonts/malgun.ttf'
font = font_manager.FontProperties(fname=font_path, size=10).get_name()

# warning 표시 끄기
warnings.simplefilter('ignore') # 경고메세지 무시 

# 기본 폰트 설정
plt.rcParams['font.family']= font
# 기본폰트 사이즈 설정 
plt.rcParams['font.size'] = 14
# 기본차트 사이즈 변경
plt.rcParams['figure.figsize'] = (8, 6)
# 기본 그리드 표시
plt.rcParams['axes.grid'] = True
# 한글화 후 - 표시가 네모로 나오는 현상 수정 
plt.rcParams['axes.unicode_minus'] = False

# %%
# 차트 시각화 
data = np.random.random(50) # 정수로 랜덤정수 50개를 만듦 (표준정규분포값)
data
# Out:
# array([3.17289123e-01, 7.25158377e-01, 8.21757378e-01, 2.72742604e-04,
#        9.94865851e-01, 2.08110452e-01, 3.49704114e-01, 2.94328717e-02,
#        8.92543501e-02, 2.25024366e-01, 1.50031182e-01, 5.00572180e-02,
#        7.03979964e-01, 8.35778798e-01, 9.47187624e-01, 9.89766370e-01,
#        9.08842567e-01, 3.34809035e-01, 1.73339794e-01, 6.17123686e-01,
#        7.11576030e-01, 8.87949011e-01, 2.38602290e-01, 7.87926699e-01,
#        9.36575819e-01, 2.79085503e-02, 4.87479313e-01, 1.97100914e-02,
#        8.22476459e-01, 3.15900775e-01, 3.00728535e-01, 3.66543069e-01,
#        1.13034282e-01, 3.37033510e-01, 6.29901706e-01, 6.61088008e-01,
#        7.93074291e-01, 4.64577347e-01, 7.18420483e-01, 4.11211583e-01,
#        1.61299532e-01, 1.92387375e-02, 4.41437838e-01, 8.95728855e-01,
#        1.11477724e-01, 3.43357127e-01, 5.61754647e-01, 8.99494559e-01,
#        4.57496019e-01, 6.93530226e-01])

# %%
# 정수생성 
np.random.randint(1,20,size=50)
# Out:
# array([18, 12, 12, 16, 16,  7,  4, 16,  8, 10, 14,  9, 19,  7, 17, 12,  2,
#        18,  5,  5,  3,  3,  1, 19,  4,  1, 17,  5,  9,  5,  6,  3,  4, 15,
#        14, 14, 18, 16, 13,  6,  9,  2,  6,  7,  4, 18,  6, 15, 16,  5])

# %%
## 차트 생성
plt.plot(np.random.randn(50), label='겨울기온')
plt.title('변화값')
plt.legend(loc='upper right') # 소숫점 제외인거같은데 
plt.show()

# %%
import numpy as np 
import seaborn as sns

sns.set(font=font, rc={'axes.unicode_minus':False}, style='darkgrid')

# %%
## 시본 차트 생성
plt.plot(np.random.randn(50), label='겨울기온')
plt.title('변화값')
plt.legend(loc='upper right') # 소숫점 제외인거같은데 
plt.show()

# %% [markdown]
# ## 판다스로 읽은 데이터 차트화

# %%
# 판다스로 데이터 
import pandas as pd

# %%
df = pd.read_csv('./data/sample_2.csv')
df
# Out:
#    Unnamed: 0 국적코드  성별    입국객수    전년동기
# 0           0  A01  남성  106320   85815
# 1           1  A01  여성  191436  125241
# 2           2  A31  남성     319     299
# 3           3  A31  여성      42      54
# 4           4  A18  남성  158912  124486
# 5           5  A18  여성  232943  163466

# %%
df[['성별','입국객수']].plot()
plt.show()

# %%
# 히스토그램 
df[['성별','입국객수']].hist(bins=5)
plt.title('2021년 입국객수')
plt.show()

# %%
# 스캐터차트 
x = np.random.randint(-100, 100, 50) #-100 ~ 100 사이에 50개만 랜덤
y = np.random.randint(-200, 200, 50)
size = np.random.randint(-10, 200, 50)
color = np.random.randint(0, 100, 50)

plt.scatter(x, y, s=size, c=color, alpha=0.4)
plt.colorbar()
plt.show()

# %%
## 파이차트
size = [2441, 2312, 1031, 1233]
label = ['A','B','AB','O']
color = ['darkmagenta','deeppink','hotpink','pink']

plt.axis('equal') # 가로축, 세로축 스케일 동일
plt.pie(size,labels=label, autopct='%.1f%%', explode=(0,0,0.1,0),colors=color)
plt.legend(loc='lower left')
plt.title('혈액형별 분포')
plt.show()
