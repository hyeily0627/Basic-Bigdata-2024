# %% [markdown]
# ### 스타벅스 매장 입지 분석
# - 순서
#     1. 데이터 수집
#     2. 데이터 전처리
#     3. 분석
#     4. 시각화
#
# ### 데이터 수집
# - 셀레니움 자동화 + 뷰티풀수프 정제

# %%
# 필요라이브러리 설치 
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup

# %%
# %pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\dev\langs\python311\lib\site-packages (4.66.4)
# Requirement already satisfied: colorama in c:\users\administrator\appdata\roaming\python\python311\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 분석, 시각화 라이브러리 사용 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib import rcParams, rc, font_manager
import warnings
import seaborn as sns 
import time
from tqdm import tqdm  # 반복 진행 프로그래스바 모듈

# %%
# 맷플롯립 한글 및 기타 설정 
font_path = 'C:/Windows/Fonts/malgun.ttf'
font = font_manager.FontProperties(fname=font_path, size=10).get_name()
# 기본 폰트 설정
plt.rcParams['font.family']= font
# 기본폰트 사이즈 설정 
plt.rcParams['font.size'] = 14
# 기본차트 사이즈 변경
plt.rcParams['figure.figsize'] = (8, 6)
# 기본 그리드 표시
plt.rcParams['axes.grid'] = True
# 한글화 후 - 표시가 네모로 나오는 현상 수정 
plt.rcParams['axes.unicode_minus'] = False

# warning 표시 끄기
warnings.simplefilter('ignore') # 경고메세지 무시 

# 시본 설정 
sns.set_theme(font=font, rc={'axes.unicode_minus':False}, style='white')

# %% [markdown]
# ### 셀레니움 사용

# %%
# 웹드라이버 
driver = webdriver.Chrome()

# %%
# 스타벅스 코리아 사이트 연결 
url = 'https://www.starbucks.co.kr/store/store_map.do?disp=quick'
driver.get(url)

# %%
# 매장 찾기 웹소스에서 '지역검색' 링크 검색 후 링크 클릭
## F12 개발자도구로 HTML 태그 정보 확인
## header.loca_search > h3 > a 에 지역 검색 링크 존재
link_path = 'header.loca_search > h3 > a'
driver.find_element(By.CSS_SELECTOR, link_path).click() #find_elements는 여러개 찾는거

# %%
# 지역검색에서 서울 링크 클릭 
# ul.sido_arae_box > li:nth-child(1) > a
link_path = 'ul.sido_arae_box > li:nth-child(1) > a'
driver.find_element(By.CSS_SELECTOR, link_path).click()

# %%
# 서울에서 전체 링크 클릭 
# ul.gugun_arae_box > li:nth-child(1) > a
link_path = 'ul.gugun_arae_box > li:nth-child(1) > a'
driver.find_element(By.CSS_SELECTOR, link_path).click()

# 매장 전체 조회시 최초 2-3초 정도 시간이 걸리기때문에 딜레이를 걸어줌
time.sleep(3.0)

# %% [markdown]
# ### 서울 스타벅스 매장 정보 가져오기

# %%
html = driver.page_source

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
# 서울 전체 결과에서 
## ul.quickSearchResultBoxSidoGugun > li.quickResultLstCon 만 가져오면 됨

quickResultLst = soup.select('li.quickResultLstCon')
len(quickResultLst)
# Out:
# 637

# %%
# 각 결과 확인
quickResultLst[23] 
# 부산 현재 위치에서 나온 23개의 결과가 서울과 중첩되어 나오는 현상이 있음!!
# 우리 잘못 아니얌~~
# Out:
# <li class="quickResultLstCon" data-code="3762" data-hlytag="null" data-index="0" data-lat="37.501087" data-long="127.043069" data-name="역삼아레나빌딩" data-storecd="1509" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼아레나빌딩" data-store="1509" data-yn="N">역삼아레나빌딩  </strong> <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>

# %% [markdown]
# ### pandas 데이터 처리

# %%
#quickResultLst[23].select('strong')[0].text
quickResultLst[23] ## 왜 나는 20번이 강사님이랑 똑같죵,,?
# Out:
# <li class="quickResultLstCon" data-code="3762" data-hlytag="null" data-index="0" data-lat="37.501087" data-long="127.043069" data-name="역삼아레나빌딩" data-storecd="1509" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼아레나빌딩" data-store="1509" data-yn="N">역삼아레나빌딩  </strong> <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>

# %%
# 서울 매장 리스트 DF
seoulStores = []

for item in tqdm(quickResultLst):   # 진행률 표시
    storeName = item.select('strong')[0].text.strip() # 매장이름
    storeLat = item['data-lat'] # 매장위치 위도값
    storeLng = item['data-long'] # 매장위치 경도 값
    address = item.select('p.result_details')[0].text.replace('1522-3232','') # 매장 주소
    storeCd = item['data-storecd'] # 매장코드(번호가 작을수록 오랜된 매장이라고 유추)
    storeType = item.select('i')[0]['class'][0].split('_')[1]   # 매장종류(일반,리저브,DT,WT)

    seoulStores.append([storeCd, storeName,storeType,address,storeLat,storeLng])
    time.sleep(0.1)
# Out:
# 100%|██████████| 637/637 [01:04<00:00,  9.83it/s]

# %%
# 리스트 확인
len(seoulStores)
# Out:
# 637

# %%
# pandas DF로 변환
df_seoulStore = pd.DataFrame(seoulStores, columns=['매장코드','매장명','매장종류','주소','위도','경도'])
df_seoulStore.head(2)
# Out:
#    매장코드     매장명       매장종류                      주소                 위도  \
# 0  1190   동명대DT  generalDT  부산광역시 남구 신선로 423 (용당동)  35.12311959047579
# 1  2235  부산유엔공원    general  부산광역시 남구 유엔로 200 (대연동)         35.1299808
#
#                    경도
# 0  129.09901642703608
# 1         129.0980971

# %%
df_seoulStore.tail(2)
# Out:
#      매장코드  매장명     매장종류                         주소                 위도  \
# 635  2002  양원역  general  서울특별시 중랑구 양원역로10길 3 (망우동)   37.6066536267232
# 636  1749  중화역  general       서울특별시 중랑구 봉화산로 35 1층  37.60170912407773
#
#                      경도
# 635    127.106359790053
# 636  127.07841136432036

# %%
# 데이터 저장
df_seoulStore.to_csv('./data/스타벅스_서울매장정보.csv', encoding='utf-8')

# %% [markdown]
# #### 데이터 전처리
# - 데이터로 통계를 낼 때 문제가 없도록 데이터를 사전에 처리 해주는 것
# - 데이터 전처리가 빅데이터 분석 전체 프로젝트의 50%를 차지할 정도로 비중이 높다.
# - 전처리 케이스
# 1. ❗데이터 결측치 확인
#     - Null, NAN, '', empty 등 값이 없는 컬럼을 제거/유용한 값으로 치환
#     - Null, NAN은 통계 계산시 계산된 값도 Null로 바뀜
#     - 숫자로 된 컬럼 값에는 결측치 제거/변경이 필수🚨
# 2. 필요없는 컬럼/행 제거
# 3. 필요하지만 없는 컬럼 추가
# 4. 잘못 된 값 변경

# %%
# 전체 데이터에서 주소에 부산광역시가 포함 여부를 출력함 
df_seoulStore['주소'].str.contains('부산광역시')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 632    False
# 633    False
# 634    False
# 635    False
# 636    False
# Name: 주소, Length: 637, dtype: bool

# %%
# 부산광역시가 포함된 인덱스 출력 
del_list = df_seoulStore[df_seoulStore['주소'].str.contains('부산광역시')].index

# %%
# 서울이 아닌 인덱스 값을 삭제(drop)
df_seoulStore.drop(del_list)
# Out:
#      매장코드      매장명     매장종류                                     주소  \
# 23   1509  역삼아레나빌딩  general                서울특별시 강남구 언주로 425 (역삼동)
# 24   1434   논현역사거리  general               서울특별시 강남구 강남대로 538 (논현동)
# 25   1595  신사역성일빌딩  general               서울특별시 강남구 강남대로 584 (논현동)
# 26   1527   국기원사거리  general               서울특별시 강남구 테헤란로 125 (역삼동)
# 27   1468   대치재경빌딩  general             서울특별시 강남구 남부순환로 2947 (대치동)
# ..    ...      ...      ...                                    ...
# 632   838     사가정역  general                      서울특별시 중랑구 면목로 310
# 633   493      상봉역  general                서울특별시 중랑구 망우로 307 (상봉동)
# 634  1668       묵동  general  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층
# 635  2002      양원역  general              서울특별시 중랑구 양원역로10길 3 (망우동)
# 636  1749      중화역  general                   서울특별시 중랑구 봉화산로 35 1층
#
#                     위도                  경도
# 23           37.501087          127.043069
# 24           37.510178          127.022223
# 25          37.5139309         127.0206057
# 26           37.499517          127.031495
# 27           37.494668          127.062583
# ..                 ...                 ...
# 632          37.579594          127.087966
# 633           37.59689           127.08647
# 634          37.615368          127.076633
# 635   37.6066536267232    127.106359790053
# 636  37.60170912407773  127.07841136432036
#
# [614 rows x 6 columns]

# %% [markdown]
# - drop 등 몇가지 함수는 값을 적용 하는 것이 아니라, 실행시 값이 바뀐걸 보여주는 함수임
# - 값을 아예 변경하려면,
# 1. 새로운 변수나 같은 변수에 다시 할당 하거나
# 2. 속성 중 inplace = true 로 설정

# %%
# 1. drop() 함수로 
df_seoulStore
# Out:
#      매장코드     매장명       매장종류                                     주소  \
# 0    1190   동명대DT  generalDT                 부산광역시 남구 신선로 423 (용당동)
# 1    2235  부산유엔공원    general                 부산광역시 남구 유엔로 200 (대연동)
# 2     683   부산대연역    general           부산광역시 남구 수영로 240-1, 1층 (대연동)
# 3    1795  부산대연못골    general                  부산광역시 남구 못골로 87 (대연동)
# 4     248     경성대    general                 부산광역시 남구 수영로 312 (대연동)
# ..    ...     ...        ...                                    ...
# 632   838    사가정역    general                      서울특별시 중랑구 면목로 310
# 633   493     상봉역    general                서울특별시 중랑구 망우로 307 (상봉동)
# 634  1668      묵동    general  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층
# 635  2002     양원역    general              서울특별시 중랑구 양원역로10길 3 (망우동)
# 636  1749     중화역    general                   서울특별시 중랑구 봉화산로 35 1층
#
#                      위도                  경도
# 0     35.12311959047579  129.09901642703608
# 1            35.1299808         129.0980971
# 2    35.134998534278104   129.0930603381513
# 3     35.13609516236527  129.09191736599408
# 4    35.137345553736964  129.10063775537583
# ..                  ...                 ...
# 632           37.579594          127.087966
# 633            37.59689           127.08647
# 634           37.615368          127.076633
# 635    37.6066536267232    127.106359790053
# 636   37.60170912407773  127.07841136432036
#
# [637 rows x 6 columns]

# %%
# 2. inplace=true  사용
df_seoulStore.drop(del_list, inplace=True)

# %%
df_seoulStore
# Out:
#      매장코드      매장명     매장종류                                     주소  \
# 23   1509  역삼아레나빌딩  general                서울특별시 강남구 언주로 425 (역삼동)
# 24   1434   논현역사거리  general               서울특별시 강남구 강남대로 538 (논현동)
# 25   1595  신사역성일빌딩  general               서울특별시 강남구 강남대로 584 (논현동)
# 26   1527   국기원사거리  general               서울특별시 강남구 테헤란로 125 (역삼동)
# 27   1468   대치재경빌딩  general             서울특별시 강남구 남부순환로 2947 (대치동)
# ..    ...      ...      ...                                    ...
# 632   838     사가정역  general                      서울특별시 중랑구 면목로 310
# 633   493      상봉역  general                서울특별시 중랑구 망우로 307 (상봉동)
# 634  1668       묵동  general  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층
# 635  2002      양원역  general              서울특별시 중랑구 양원역로10길 3 (망우동)
# 636  1749      중화역  general                   서울특별시 중랑구 봉화산로 35 1층
#
#                     위도                  경도
# 23           37.501087          127.043069
# 24           37.510178          127.022223
# 25          37.5139309         127.0206057
# 26           37.499517          127.031495
# 27           37.494668          127.062583
# ..                 ...                 ...
# 632          37.579594          127.087966
# 633           37.59689           127.08647
# 634          37.615368          127.076633
# 635   37.6066536267232    127.106359790053
# 636  37.60170912407773  127.07841136432036
#
# [614 rows x 6 columns]

# %%
# DF 인덱스가 0이 아닌 값을 시작, 인덱스 초기화
## drop=Ture 는 인덱스 삭제, inplace = true 값 작전 전용(커밋처럼)
df_seoulStore.reset_index(inplace=True, drop=True)

# %%
# 단순히 컬럼을 삭제할 떄 
## axis=0 행삭제 , axis=컬럼 
df_seoulStore.drop(['index'], axis=1, inplace=True)

# %%
df_seoulStore
# Out:
#      매장코드      매장명     매장종류                                     주소  \
# 0    1509  역삼아레나빌딩  general                서울특별시 강남구 언주로 425 (역삼동)
# 1    1434   논현역사거리  general               서울특별시 강남구 강남대로 538 (논현동)
# 2    1595  신사역성일빌딩  general               서울특별시 강남구 강남대로 584 (논현동)
# 3    1527   국기원사거리  general               서울특별시 강남구 테헤란로 125 (역삼동)
# 4    1468   대치재경빌딩  general             서울특별시 강남구 남부순환로 2947 (대치동)
# ..    ...      ...      ...                                    ...
# 609   838     사가정역  general                      서울특별시 중랑구 면목로 310
# 610   493      상봉역  general                서울특별시 중랑구 망우로 307 (상봉동)
# 611  1668       묵동  general  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층
# 612  2002      양원역  general              서울특별시 중랑구 양원역로10길 3 (망우동)
# 613  1749      중화역  general                   서울특별시 중랑구 봉화산로 35 1층
#
#                     위도                  경도
# 0            37.501087          127.043069
# 1            37.510178          127.022223
# 2           37.5139309         127.0206057
# 3            37.499517          127.031495
# 4            37.494668          127.062583
# ..                 ...                 ...
# 609          37.579594          127.087966
# 610           37.59689           127.08647
# 611          37.615368          127.076633
# 612   37.6066536267232    127.106359790053
# 613  37.60170912407773  127.07841136432036
#
# [614 rows x 6 columns]

# %%
# 전처리 완료한 DF 저장
df_seoulStore.to_csv('./data/스타벅스_서울매장정보_최종.csv', encoding='utf-8')

# %% [markdown]
# ### 전국 시군구 위도경도

# %%
#  전국 시군구 위경도 엑셀파일 로드
df_koreaManicipality = pd.read_excel('./data/전국_시군구_위경도.xlsx')

# %%
df_koreaManicipality.tail()
# Out:
#       docity  do   city   longitude   latitude
# 290    충청충주시  충청    충주시  127.928144  36.988181
# 291    충청태안군  충청    태안군  126.299975  36.742667
# 292  충청한누리대로  충청  한누리대로  127.289926  36.485450
# 293    충청홍성군  충청    홍성군  126.662908  36.598361
# 294    충청대전시  충청    대전시  127.384862  36.350630

# %%
# 서울구별 데이터 필터링 
seoulList = df_koreaManicipality['do'] == '서울'

# %%
df_seoulManicipality = df_koreaManicipality[seoulList]

# %%
df_koreaManicipality.reset_index(drop=True, inplace=True)

# %%
df_koreaManicipality.tail()
# Out:
#    docity  do city   longitude   latitude
# 20  서울용산구  서울  용산구  126.967522  37.536094
# 21  서울은평구  서울  은평구  126.931242  37.599969
# 22  서울종로구  서울  종로구  126.981642  37.570378
# 23   서울중구  서울   중구  126.999642  37.561003
# 24  서울중랑구  서울  중랑구  127.094778  37.603806

# %%
# 서울구별 위치값 저장 
df_seoulManicipality.to_csv('./data/서울구별위치.csv', encoding='utf-8')

# %%
# DF 정보확인 / 데이터 결측치, 타입 확인
df_seoulStore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   매장코드    614 non-null    object
#  1   매장명     614 non-null    object
#  2   매장종류    614 non-null    object
#  3   주소      614 non-null    object
#  4   위도      614 non-null    object
#  5   경도      614 non-null    object
# dtypes: object(6)
# memory usage: 28.9+ KB
